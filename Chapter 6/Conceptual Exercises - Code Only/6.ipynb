# %% [markdown]
# ### 6.a. Solving for ridge regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
y = 10.0
lamb = 24.5
FX = []
BETA = []
steps = np.linspace(-100, 100, 20000)
for beta in steps:
    fx = (y - beta)**2 + (lamb*(beta**2))
    FX.append(fx)
    BETA.append(beta)

# %%
plt.xkcd()
plt.figure(figsize=(11, 5))
plt.plot(BETA, FX, color = 'green')

# %%
df = pd.DataFrame([BETA, FX]).T
df.columns = ['BETA', 'FX']
df.head()
# Out:
#          BETA             FX
# 0 -100.000000  257100.000000
# 1  -99.989999  257048.799990
# 2  -99.979999  256997.605081
# 3  -99.969998  256946.415272
# 4  -99.959998  256895.230564

# %%
mindf = min(df['FX'])
mindf
# Out:
# 96.07864037384078

# %%
df.loc[df['FX'] == mindf]
# Out:
#           BETA        FX
# 10039  0.39502  96.07864

# %% [markdown]
# *So, the corresponding BETA value for the least value (=96.120047) for FX is 0.351759. I will now input the values for
# $y_j$ and $\lambda$ to find the estimate and see if they are equivalent.*

# %%
beta_est = y / (1 + lamb)
beta_est
# Out:
# 0.39215686274509803

# %% [markdown]
# **Therefore, we can see that the estimated $\beta$ is a good approximation for the beta that gives the least value of fx.**

# %% [markdown]
# ### 6.b. Solving for lasso regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Case 1: $y_j$ > $\lambda$/2

# %%
y = 10.0
lamb = 5.5
FX = []
BETA = []
steps = np.linspace(-100, 100, 20000)
for beta in steps:
    fx = (y - beta)**2 + (lamb*np.abs(beta))
    FX.append(fx)
    BETA.append(beta)

# %%
plt.xkcd()
plt.figure(figsize=(11, 5))
plt.plot(BETA, FX, color = 'green')

# %%
df = pd.DataFrame([BETA, FX]).T
df.columns = ['BETA', 'FX']
df.head()
# Out:
#          BETA            FX
# 0 -100.000000  12650.000000
# 1  -99.989999  12647.744987
# 2  -99.979999  12645.490175
# 3  -99.969998  12643.235562
# 4  -99.959998  12640.981149

# %%
mindf = min(df['FX'])
mindf
# Out:
# 47.437521508557055

# %%
df.loc[df['FX'] == mindf]
# Out:
#            BETA         FX
# 10724  7.245362  47.437522

# %% [markdown]
# *So, the corresponding BETA value for the least value (=47.437522) for FX is 7.245362. I will now input the values for
# $y_j$ and $\lambda$ to find the estimate and see if they are equivalent.*

# %%
beta_est = y - (lamb / 2)
beta_est
# Out:
# 7.25

# %% [markdown]
# **Therefore, we can see that the estimated $\beta$ is a good approximation for the beta that gives the least value of fx.**

# %% [markdown]
# #### Case 2: $y_j$ < -$\lambda$/2

# %%
y = -100.0
lamb = 25
FX = []
BETA = []
steps = np.linspace(-100, 100, 20000)
for beta in steps:
    fx = (y - beta)**2 + (lamb*np.abs(beta))
    FX.append(fx)
    BETA.append(beta)

# %%
plt.xkcd()
plt.figure(figsize=(11, 5))
plt.plot(BETA, FX, color = 'green')

# %%
df = pd.DataFrame([BETA, FX]).T
df.columns = ['BETA', 'FX']
df.head()
# Out:
#          BETA           FX
# 0 -100.000000  2500.000000
# 1  -99.989999  2499.750088
# 2  -99.979999  2499.500375
# 3  -99.969998  2499.250863
# 4  -99.959998  2499.001550

# %%
mindf = min(df['FX'])
mindf
# Out:
# 2343.750000390664

# %%
df.loc[df['FX'] == mindf]
# Out:
#            BETA       FX
# 1250 -87.499375  2343.75

# %% [markdown]
# *So, the corresponding BETA value for the least value (=2343.75) for FX is -87.499375. I will now input the values for
# $y_j$ and $\lambda$ to find the estimate and see if they are equivalent.*

# %%
beta_est = y + (lamb / 2)
beta_est
# Out:
# -87.5

# %% [markdown]
# **Therefore, we can see that the estimated $\beta$ is a good approximation for the beta that gives the least value of fx.**

# %% [markdown]
# #### Case 3: |$y_j$| $\leq$ $\lambda$/2

# %%
y = -10.0
lamb = 25
FX = []
BETA = []
steps = np.linspace(-100, 100, 20000)
for beta in steps:
    fx = (y - beta)**2 + (lamb*np.abs(beta))
    FX.append(fx)
    BETA.append(beta)

# %%
plt.xkcd()
plt.figure(figsize=(11, 5))
plt.plot(BETA, FX, color = 'green')

# %%
df = pd.DataFrame([BETA, FX]).T
df.columns = ['BETA', 'FX']
df.head()
# Out:
#          BETA            FX
# 0 -100.000000  10600.000000
# 1  -99.989999  10597.949998
# 2  -99.979999  10595.900195
# 3  -99.969998  10593.850593
# 4  -99.959998  10591.801190

# %%
mindf = min(df['FX'])
mindf
# Out:
# 100.02502625256268

# %%
df.loc[df['FX'] == mindf]
# Out:
#        BETA          FX
# 9999 -0.005  100.025026

# %% [markdown]
# **So, the corresponding BETA value for the lowest fx(=100.025026) is $\approx$0. Therefore, 0 is a good approximation of the BETA that gives the least value of fx.**
